# %% [markdown]
# #House Price Prediction using Linear Regression

# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
dataframe=pd.read_csv('/content/housing_data.csv')

# %% [markdown]
# ##Histogram for Area

# %%
plt.hist('area')
plt.show()

# %% [markdown]
# ##Scatter Plot between Price and Stories

# %%
x= dataframe['stories']
y= dataframe['price']
plt.scatter(x,y)
plt.show()

# %% [markdown]
# ##Heatmap Visualization

# %%
correlationMatrix=dataframe.corr()

# %%
import seaborn as sns

# %%
sns.heatmap(correlationMatrix,cmap="YlGnBu",annot=True)
# Out:
# <Axes: >

# %% [markdown]
# ##Model Training

# %%
from sklearn.linear_model import LinearRegression

# %%
model = LinearRegression()

# %%
x = dataframe[['area', 'bedrooms']]
y = dataframe['price']

# %%
model.fit(x, y)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(x)

# %%
from sklearn.model_selection import train_test_split

# %%
xtrain, xtest, ytrain, ytest = train_test_split(
    x, y, test_size=20, random_state=80)

# %%
from sklearn.metrics import r2_score

# %%
f= y_pred

# %% [markdown]
# ##R2-Score

# %%
r2 = r2_score(y, f)
print(r2)
# Out:
# 0.37049285246705077

# %% [markdown]
# ##Prediction for New House

# %%
new_house = pd.DataFrame([[2000, 3]], columns=["area", "bedrooms"])

predicted_price = model.predict(new_house)

print("Predicted Price:", predicted_price[0])
# Out:
# Predicted Price: 3457380.5053303465
